# %% [markdown]
# ### Import packages and set config

# %%
# runn it only once. 
# It will change the current directory to the root of the project
import os
os.chdir(os.path.dirname(os.path.abspath('.')))

# %%
import pandas as pd
import numpy as np

from metrics import evaluate_clustering_performance
from plots import plot_si_da_ca, plot_tsne

# %% [markdown]
# ## Clustering analysis with 'Text to Num' disabled"

# %%
embedding_from_last_layer_text_disabled = pd.read_csv('./olist_gpt2-medium_20_False/embeddings_from_last_layer.csv')
embedding_from_all_layers_text_disabled = pd.read_csv('./olist_gpt2-medium_20_False/embeddins_from_all_layers.csv')

# %% [markdown]
# ### Determining The Optimal Number Of Clusters

# %% [markdown]
# #### Embeddings from last layer

# %%
plot_si_da_ca(embedding_from_last_layer_text_disabled)

# %%
OPTIMAL_CLUSTERS = 2
evaluate_clustering_performance(embedding_from_last_layer_text_disabled, OPTIMAL_CLUSTERS)
# Out:
# Number of clusters: 2
# Silhouette Score 0.7409540991409803
# Davies-Bouldin Index 0.35229528153577794
# Calinski Harabasz Score 55575.97823516519
# (0.7409540991409803, 0.35229528153577794, 55575.97823516519)

# %% [markdown]
# #### Embeddings from all layers

# %%
plot_si_da_ca(embedding_from_all_layers_text_disabled)

# %%
OPTIMAL_CLUSTERS = 2
evaluate_clustering_performance(embedding_from_all_layers_text_disabled, OPTIMAL_CLUSTERS)
# Out:
# Number of clusters: 2
# Silhouette Score 0.5570389418466399
# Davies-Bouldin Index 0.5958418277829517
# Calinski Harabasz Score 34171.916554639654
# (0.5570389418466399, 0.5958418277829517, 34171.916554639654)

# %% [markdown]
# ## Clustering analysis with 'Text to Num' enalbed

# %%
embedding_from_last_layer_text_enabled = pd.read_csv('./olist_gpt2-medium_20_True/embeddings_from_last_layer.csv')
embedding_from_all_layers_text_enabled = pd.read_csv('./olist_gpt2-medium_20_True/embeddins_from_all_layers.csv')

# %% [markdown]
# ### Determining The Optimal Number Of Clusters

# %% [markdown]
# #### Embeddings from last layer

# %%
plot_si_da_ca(embedding_from_last_layer_text_enabled)

# %%
OPTIMAL_CLUSTERS = 2
evaluate_clustering_performance(embedding_from_last_layer_text_enabled, OPTIMAL_CLUSTERS)
# Out:
# Number of clusters: 2
# Silhouette Score 0.772904875570052
# Davies-Bouldin Index 0.3231093031754887
# Calinski Harabasz Score 62036.86877062415
# (0.772904875570052, 0.3231093031754887, 62036.86877062415)

# %%
plot_si_da_ca(embedding_from_all_layers_text_enabled)

# %%
OPTIMAL_CLUSTERS = 2
evaluate_clustering_performance(embedding_from_all_layers_text_enabled, OPTIMAL_CLUSTERS)
# Out:
# Number of clusters: 2
# Silhouette Score 0.5568694173923526
# Davies-Bouldin Index 0.5984847330499032
# Calinski Harabasz Score 33410.79939503672
# (0.5568694173923526, 0.5984847330499032, 33410.79939503672)
